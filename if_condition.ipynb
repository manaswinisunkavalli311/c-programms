# %% [markdown]
# <a href="https://colab.research.google.com/github/manaswinisunkavalli311/c-programms/blob/main/if_condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter age"))
if a>=18:
  print("eligible")
else:
  print("not eligible")
# Out:
# enter age12
# not eligible

# %%
a=78
if a>=18:
    print("eligible")
else:
  print("not eligible")
# Out:
# eligible

# %%
# max of 3 num
a=10
b=3
c=6
if a>b and a>c:
  print("a is max")
elif b>c and b>a:
    print("b is max")
else:
      print("c is max")
# Out:
# a is max

# %%
a=int(input("a value"))
b=int(input("b value"))
c=int(input("c value"))
if a>b and a>c:
  print("a is max")
elif b>c and b>a:
    print("b is max")
else:
  print("c is max")
# Out:
# a value3
# b value4
# c value5
# c is max

# %%
a=int(input("enter s1"))
b=int(input("sub 2"1))
c=int(input("sub 3"))
d=int(input("sub 4"))
e=int(input("sub 5"))
if a>b and a>c and  a>d and a>e:
    print("a is max")
elif b>a and b>c and b>d and b>e:
   print("b is max")
elif c>a and c>b and c>d and c>e:
  print("c is max")
elif d>a and d>b and d>c and d>e:
  print("d is max")
else:
  print("e is max")
# Out:
# enter s112
# sub 213
# sub 34
# sub 45
# sub 56
# b is max

# %%
a=int(input("s1"))
b=int(input("s2"))
c=int(input("s3"))
if a==b==c:
  print("equi")
elif a ==b!=c:
  print("iso")
else:
  print("scalene")
# Out:
# s130
# s240
# s320
# scalene

# %%
ch=(input(" enter ch"))
if (ch=='a' or ch=='A' or ch=='e' or ch=='E' or  ch=='o'or ch=='O' or ch=='i' or ch=='I' or ch=='u' or ch=='U'):
    print(ch,"vowel")
else:
  print(ch,"consonant")
# Out:
#  enter chh
# h consonant
