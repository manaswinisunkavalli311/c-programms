# %% [markdown]
# <a href="https://colab.research.google.com/github/manaswinisunkavalli311/c-programms/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p=float(input("p"))
t=float(input("t"))
r=float(input("r"))
si=(p*t*r)/100
print(si)
# Out:
# p1200
# t2
# r5.4
# si

# %%
a=int(input("basic"))
b=int(input("da"))
c=int(input("hra"))
d=int(input("pf"))
e=int(input("lic"))
net_salary=a+b+c-d-e
print(net_salary)
# Out:
# basic56
# da89
# hra78
# pf56
# lic56
# 111

# %%
a=int(input("a"))
b=int(input("b"))
rem=a-((a//b)*b)
print(rem)
# Out:
# a9
# b2
# 1

# %%
a=int(input("a"))
b=int(input("b"))
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# a3
# b4
# 4
# 3

# %%
a=int(input("s1"))
b=int(input("s2"))
s3=a+b
print(s3)
# Out:
# s134
# s230
# 64

# %%
a=int(input("num"))
bit=int(input("enter"))
num=num>>(bit-1)
if((num&1)!=0):
  print("{} is set")
else:
  print(" {} is unset")
# Out:
# num83
# enter81
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-b718b8a9cc1f> in <module>()
#       1 a=int(input("num"))
#       2 bit=int(input("enter"))
# ----> 3 num=num>>(bit-1)
#       4 if((num&1)!=0):
#       5   print("{} is set")
#
# NameError: name 'num' is not defined

# %%
year=int(input("year"))
if(year%4)==0:
  print("leap year")
else:
  print("not leap year")
# Out:
# year2016
# leap year

# %%
ch=(input("enter"))
if(ch>='A' and ch<='Z'):
  ch=ch+32
  print("%c",ch)
else:
  ch=ch-32
  print("%c",ch)
# Out:
# enterg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-2ff104a18f35> in <module>()
#       4   print("%c",ch)
#       5 else:
# ----> 6   ch=ch-32
#       7   print("%c",ch)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
a=int(input("enter"))
if a>0:
  print("positive")
elif a<0:
  print("negative")
else:
  print("zero")
# Out:
# enter0
# zero

# %%
num=(input("enter"))
i=0
for i in range(len(num)):
     if num[i]!=num[-1-i]:
       print('not')
       break
     else:
      print('palindrome')
      break
# Out:
# enter777
# palindrome

# %%
num=int(input("enter"))
fact=1
if(num<0):
  print("no")
elif num==0:
    print("fact of 0 is 1")
else:
      for i in range(1,num+1):
        fact=fact*i
        print(fact)
# Out:
# enter7
# 1
# 2
# 6
# 24
# 120
# 720
# 5040

# %%
num=int(input("enter num"))
sum=0
for i in range (1,num):
      if(num%i==0):
           sum=sum+i
if(sum==num):
     print("perfect")
else:
  print("not")
# Out:
# enter num28
# perfect

# %%
decimal=int(input("enter"))
bin=0
ctr=0
temp=decimal
while(temp>0):
      bin=((temp%2)*(10**ctr))+bin
      temp=int(temp/2)
      ctr+=1
      print("binary of {x} is {y}".format(x=decimal,y=bin))
# Out:
# enter3
# binary of 3 is 1
# binary of 3 is 11

# %%
n=int(input("enter"))
for i in range(1,n+1):
  if(i%2==0):
    print(i)
# Out:
# enter8
# 2
# 4
# 6
# 8
