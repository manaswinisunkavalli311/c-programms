# %% [markdown]
# <a href="https://colab.research.google.com/github/manaswinisunkavalli311/c-programms/blob/main/plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6,8,9])
ypoints = np.array([0, 20,33,71])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([])
ypoints = np.array([])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["chem", "IT ", "math1", "math2","python","vdc","eng","mech"])
y = np.array([30,35,45,67,89,56,77,90])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2,3,4,5,6])
ypoints = np.array([17,23,45,65,54])

plt.plot(xpoints, ypoints,marker='o',color='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()
